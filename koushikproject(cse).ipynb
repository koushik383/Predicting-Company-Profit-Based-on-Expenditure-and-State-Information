# %% [markdown]
# # Problem Statement

# %% [markdown]
# # Title : Predicting Company Profit Based on Expenditure and State Information

# %% [markdown]
# # Background:

# %%
Understanding the factors that contribute to a company's profitability is critical for strategic planning and decision-making. 
Companies allocate their budgets across various areas such as productivity enhancements, management expenses, and promotional activities
with the expectation that these investments will lead to increased profits. This dataset contains data on the expenditures in these areas
for various companies, along with their respective states and resulting profit figures.

# %% [markdown]
# # Objective

# %%
The goal of this analysis is to build a predictive model that can accurately forecast a company's profit based on its expenditures in productivity, management, and promotions, as well as its state of operation. This model will aid in identifying the key drivers of profit and help companies optimize their budget allocations to maximize profitability.
Dataset Description:
The dataset consists of the following columns:
Productivity_Exp: Amount spent on productivity-related expenses (in thousands of dollars).
Management_Exp: Amount spent on management-related expenses (in thousands of dollars).
Promotions_Exp: Amount spent on promotional activities (in thousands of dollars).
State: The state in which the company operates.
Profit: The profit of the company (in thousands of dollars).

# %% [markdown]
# # Import data set

# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt
df=pd.read_csv("companies.csv")
df
# Out:
#     Productivity_Exp  Management_Exp  Promotions_Exp       State     Profit
# 0          220349.20       236897.80       521784.10       Texas  242261.83
# 1          217597.70       251377.59       493898.53    Illinois  241792.06
# 2          208441.51       201145.55       457934.54  Washington  241050.39
# 3          199372.41       218671.85       433199.62       Texas  232901.99
# 4          197107.34       191391.77       416168.42  Washington  216187.94
# 5          186876.90       199814.71       412861.36       Texas  206991.12
# 6          189615.46       247198.87       177716.82    Illinois  206122.51
# 7          185298.13       245530.06       373876.68  Washington  205752.60
# 8          175542.52       248718.95       361613.29       Texas  202211.77
# 9          178334.88       208679.17       354981.62    Illinois  199759.96
# 10         156913.08       210594.11       279160.95  Washington  196121.95
# ...

# %%
df.tail()
# Out:
#     Productivity_Exp  Management_Exp  Promotions_Exp       State     Profit
# 45          56000.23       224153.04        51903.93       Texas  114926.08
# 46          56315.46       215816.21       347114.46  Washington   99490.75
# 47          55000.00       235426.92        50000.00    Illinois   92559.73
# 48          55542.05       151743.15        50000.00       Texas   85673.41
# 49          55000.00       216983.80        95173.06    Illinois   64681.40

# %%
df.head()
# Out:
#    Productivity_Exp  Management_Exp  Promotions_Exp       State     Profit
# 0         220349.20       236897.80       521784.10       Texas  242261.83
# 1         217597.70       251377.59       493898.53    Illinois  241792.06
# 2         208441.51       201145.55       457934.54  Washington  241050.39
# 3         199372.41       218671.85       433199.62       Texas  232901.99
# 4         197107.34       191391.77       416168.42  Washington  216187.94

# %% [markdown]
# # Initial checkup

# %%
k.shape
# Out:
# (50, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Productivity_Exp  50 non-null     float64
#  1   Management_Exp    50 non-null     float64
#  2   Promotions_Exp    50 non-null     float64
#  3   State             50 non-null     object
#  4   Profit            50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df.describe()
# Out:
#        Productivity_Exp  Management_Exp  Promotions_Exp         Profit
# count         50.000000       50.000000       50.000000      50.000000
# mean      128721.615600   221344.639600   261025.097800  162012.639200
# std        45902.256482    28017.802755   122290.310726   40306.180338
# min        55000.000000   151283.140000    50000.000000   64681.400000
# 25%        94936.370000   203730.875000   179300.132500  140138.902500
# 50%       128051.080000   222699.795000   262716.240000  157978.190000
# 75%       156602.800000   244842.180000   349469.085000  189765.977500
# max       220349.200000   282645.560000   521784.100000  242261.830000

# %%
df['Productivity_Exp'].value_counts()
# Out:
# Productivity_Exp
# 55000.00     2
# 220349.20    1
# 83663.76     1
# 127107.60    1
# 121051.52    1
# 120605.48    1
# 116994.48    1
# 116136.38    1
# 118408.86    1
# 110493.95    1
# 101426.07    1
# 101014.02    1
# 99069.95     1
# 119664.71    1
# 75229.59     1
# 93558.51     1
# 83754.33     1
# 82892.92     1
# 78640.93     1
# 70505.73     1
# 77177.74     1
# 56000.23     1
# 56315.46     1
# 130328.87    1
# 132044.01    1
# 217597.70    1
# 122532.53    1
# 208441.51    1
# 199372.41    1
# 197107.34    1
# 186876.90    1
# 189615.46    1
# 185298.13    1
# 175542.52    1
# 178334.88    1
# 156913.08    1
# 155671.96    1
# 148863.75    1
# 146992.39    1
# 174943.24    1
# 169523.61    1
# 133013.11    1
# 149657.16    1
# 146749.16    1
# 141419.70    1
# 131253.86    1
# 133389.47    1
# 128994.56    1
# 55542.05     1
# Name: count, dtype: int64

# %% [markdown]
# # Data visualization

# %%
sns.scatterplot(df,x='Productivity_Exp',y='Profit')
# Out:
# <Axes: xlabel='Productivity_Exp', ylabel='Profit'>

# %%
sns.barplot(df,x='State',y='Productivity_Exp')
# Out:
# <Axes: xlabel='State', ylabel='Productivity_Exp'>

# %%
sns.histplot(df,x='Promotions_Exp',kde=True)
# Out:
# C:\Users\KOUSHIK\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Promotions_Exp', ylabel='Count'>

# %%
sns.pairplot(df,vars=['Productivity_Exp','Management_Exp','Promotions_Exp','Profit'])
# Out:
# C:\Users\KOUSHIK\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\KOUSHIK\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\KOUSHIK\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# # Converting the categorical to numerical using get_dummies

# %%
k=pd.get_dummies(k,columns=['State'], drop_first=False)
k.head()
# Out:
#    Productivity_Exp  Management_Exp  Promotions_Exp     Profit  \
# 0         220349.20       236897.80       521784.10  242261.83
# 1         217597.70       251377.59       493898.53  241792.06
# 2         208441.51       201145.55       457934.54  241050.39
# 3         199372.41       218671.85       433199.62  232901.99
# 4         197107.34       191391.77       416168.42  216187.94
#
#    State_Illinois  State_Texas  State_Washington
# 0           False         True             False
# 1            True        False             False
# 2           False        False              True
# 3           False         True             False
# 4           False        False              True

# %% [markdown]
# # Correleation

# %%
k.corr()
# Out:
#                   Productivity_Exp  Management_Exp  Promotions_Exp    Profit  \
# Productivity_Exp          1.000000        0.241955        0.724248  0.972900
# Management_Exp            0.241955        1.000000       -0.032154  0.200717
# Promotions_Exp            0.724248       -0.032154        1.000000  0.747766
# Profit                    0.972900        0.200717        0.747766  1.000000
# State_Illinois           -0.143165       -0.015478       -0.168875 -0.145837
# State_Texas               0.039068        0.005145       -0.033670  0.031368
# State_Washington          0.105711        0.010493        0.205685  0.116244
#
#                   State_Illinois  State_Texas  State_Washington
# Productivity_Exp       -0.143165     0.039068          0.105711
# Management_Exp         -0.015478     0.005145          0.010493
# Promotions_Exp         -0.168875    -0.033670          0.205685
# Profit                 -0.145837     0.031368          0.116244
# ...

# %%
df=k.drop(columns=['Profit'])
df.tail()
# Out:
#     Productivity_Exp  Management_Exp  Promotions_Exp  State_Illinois  \
# 45          56000.23       224153.04        51903.93           False
# 46          56315.46       215816.21       347114.46           False
# 47          55000.00       235426.92        50000.00            True
# 48          55542.05       151743.15        50000.00           False
# 49          55000.00       216983.80        95173.06            True
#
#     State_Texas  State_Washington
# 45         True             False
# 46        False              True
# 47        False             False
# 48         True             False
# 49        False             False

# %%
df=k.iloc[:,3:4]
df.head()
# Out:
#       Profit
# 0  242261.83
# 1  241792.06
# 2  241050.39
# 3  232901.99
# 4  216187.94

# %% [markdown]
# # Train_test_split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df,df,test_size=0.2,random_state=2)
x_train.head()
# Out:
#     Productivity_Exp  Management_Exp  Promotions_Exp     Profit  \
# 24         132044.01       199281.34       190574.81  158552.04
# 48          55542.05       151743.15        50000.00   85673.41
# 17         149657.16       245077.58       332574.31  175370.37
# 12         148863.75       227320.38       299839.44  191585.52
# 27         127107.60       227864.55       403183.81  155008.31
#
#     State_Illinois  State_Texas  State_Washington
# 24           False         True             False
# 48           False         True             False
# 17           False         True             False
# 12           False        False              True
# 27           False         True             False

# %%
x_train.shape
# Out:
# (40, 5)

# %%
x_test.shape
# Out:
# (10, 5)

# %% [markdown]
# # Importing LinearRegression

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
x_train.head()
# Out:
#     Productivity_Exp  Management_Exp  Promotions_Exp     Profit  \
# 24         132044.01       199281.34       190574.81  158552.04
# 48          55542.05       151743.15        50000.00   85673.41
# 17         149657.16       245077.58       332574.31  175370.37
# 12         148863.75       227320.38       299839.44  191585.52
# 27         127107.60       227864.55       403183.81  155008.31
#
#     State_Illinois  State_Texas  State_Washington
# 24           False         True             False
# 48           False         True             False
# 17           False         True             False
# 12           False        False              True
# 27           False         True             False

# %%
y_train.head()
# Out:
#     Productivity_Exp  Management_Exp  Promotions_Exp     Profit  \
# 24         132044.01       199281.34       190574.81  158552.04
# 48          55542.05       151743.15        50000.00   85673.41
# 17         149657.16       245077.58       332574.31  175370.37
# 12         148863.75       227320.38       299839.44  191585.52
# 27         127107.60       227864.55       403183.81  155008.31
#
#     State_Illinois  State_Texas  State_Washington
# 24           False         True             False
# 48           False         True             False
# 17           False         True             False
# 12           False        False              True
# 27           False         True             False

# %% [markdown]
# # Fit

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Predicting test set

# %%
y_pred=regressor.predict(x_test)
y_pred
# Out:
# array([[ 8.36637600e+04,  2.27056210e+05,  2.51126820e+05,
#          1.40708190e+05,  2.22044605e-16, -2.77555756e-16,
#          1.00000000e+00],
#        [ 5.50000000e+04,  2.35426920e+05,  5.00000000e+04,
#          9.25597300e+04,  1.00000000e+00,  1.11022302e-16,
#          0.00000000e+00],
#        [ 1.21051520e+05,  2.82645560e+05,  1.68148200e+05,
#          1.53282380e+05, -3.88578059e-16, -6.66133815e-16,
#          1.00000000e+00],
#        [ 1.78334880e+05,  2.08679170e+05,  3.54981620e+05,
#          1.99759960e+05,  1.00000000e+00,  3.88578059e-16,
#         -1.66533454e-16],
#        [ 1.46992390e+05,  2.35495070e+05,  3.02664930e+05,
#          1.84307350e+05,  1.00000000e+00,  2.77555756e-16,
#         -1.11022302e-16],
#        [ 2.20349200e+05,  2.36897800e+05,  5.21784100e+05,
#          2.42261830e+05,  5.55111512e-17,  1.00000000e+00,
#         -1.11022302e-16],
#        [ 7.71777400e+04,  2.54806140e+05,  7.83347200e+04,
# ...

# %%
y_test
# Out:
#     Productivity_Exp  Management_Exp  Promotions_Exp     Profit  \
# 36          83663.76       227056.21       251126.82  140708.19
# 47          55000.00       235426.92        50000.00   92559.73
# 28         121051.52       282645.56       168148.20  153282.38
# 9          178334.88       208679.17       354981.62  199759.96
# 13         146992.39       235495.07       302664.93  184307.35
# 0          220349.20       236897.80       521784.10  242261.83
# 44          77177.74       254806.14        78334.72  115200.33
# 46          56315.46       215816.21       347114.46   99490.75
# 39          93558.51       182982.09       224999.30  131005.76
# 23         122532.53       205751.03       354768.73  158733.99
#
#     State_Illinois  State_Texas  State_Washington
# 36           False        False              True
# 47            True        False             False
# 28           False        False              True
# 9             True        False             False
# ...

# %% [markdown]
# # Mean Error

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 5.103576450338209e-11

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 8.21092563250457e-21

# %% [markdown]
# # RMSE

# %%
import pandas as pd
from sklearn.metrics import mean_squared_error
MSE=mean_squared_error(y_test,y_pred)
RMSE=MSE**0.5
print('y_test shape:', y_test.shape)
print('y_pred shape:', y_pred.shape)
y_test_values = y_test.values.flatten()
y_pred_values = y_pred.flatten()  
data_rmse={'Actual(y_test)':y_test_values,'Predicated(y_pred)':y_pred_values}
df_rmse=pd.DataFrame(data_rmse)
df_rmse
# Out:
# y_test shape: (10, 7)
# y_pred shape: (10, 7)
#    Actual(y_test)  Predicated(y_pred)
# 0        83663.76        8.366376e+04
# 1       227056.21        2.270562e+05
# 2       251126.82        2.511268e+05
# 3       140708.19        1.407082e+05
# 4           False        2.220446e-16
# ..            ...                 ...
# 65      354768.73        3.547687e+05
# 66      158733.99        1.587340e+05
# 67          False        2.775558e-16
# 68          False       -5.551115e-17
# 69           True        1.000000e+00
#
# [70 rows x 2 columns]

# %% [markdown]
# # Conclusion

# %%
The goal of this analysis is to build a predictive model that can accurately forecast a company's profit based on its expenditures in
productivity,management,and promotions,as well as its state of operation.

# %% [markdown]
# # Insights

# %%
1.Importing data set
2.Data visualization
3.Linear regression model
4.Correlation
5.Train_test_split
6.Fitting and predecting
7.Mean Error
8.RMSE
